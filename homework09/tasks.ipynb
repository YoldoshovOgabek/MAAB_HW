# %%
import sqlite3
import pandas as pd
with sqlite3.connect('population.db') as con:
    df = pd.read_sql("select * from population", con = con)

# %% [markdown]
# Task 1

# %%
df1 = df[ (df['gender'] == 'Female') & (df['state'] == 'Florida')] 
df1
# Out:
#           id first_name  last_name                          email  gender  \
# 1          2        Mia  Tuddenham        mtuddenham1@addthis.com  Female
# 48        49      Doris    Wolfers          dwolfers1c@sbwire.com  Female
# 96        97     Louisa     Lummis          llummis2o@foxnews.com  Female
# 116      117     Cicily    Rhelton          crhelton38@flavors.me  Female
# 128      129    Kirstyn     Allbon               kallbon3k@un.org  Female
# ...      ...        ...        ...                            ...     ...
# 11543  11544    Ronnica     Hearle           rhearlef5@hao123.com  Female
# 11557  11558  Cassandra   Meriguet  cmeriguetfj@cocolog-nifty.com  Female
# 11566  11567    Camilla     Likely       clikelyfs@friendfeed.com  Female
# 11570  11571       Edin   Martinec           emartinecfw@admin.ch  Female
# 11626  11627    Melania    Laville       mlavillehg@canalblog.com  Female
#
#         salary    state
# 1       154398  Florida
# 48      278456  Florida
# ...

# %% [markdown]
# Task 2

# %%
df2 = df[ df['email'].str.endswith('@apache.org') ]
df2
# Out:
#           id first_name    last_name                      email  gender  \
# 15        16   Bearnard       Bazire        bbaziref@apache.org    Male
# 667      668     Vachel  Fareweather  vfareweatherij@apache.org    Male
# 1994    1995       Redd        Reeds        rreedsrm@apache.org    Male
# 2141    2142    Shaughn     Petrussi     spetrussi3x@apache.org    Male
# 2486    2487    Norbert     Sharpley     nsharpleydi@apache.org    Male
# 2707    2708   Hugibert       Kilrow       hkilrowjn@apache.org    Male
# 3025    3026     Winnie      Anersen       wanersenp@apache.org  Female
# 3894    3895      Johny       Mushet       jmushetou@apache.org    Male
# 3980    3981   Thedrick     Clohisey     tclohiseyr8@apache.org    Male
# 4128    4129   Mohandas       Heskey       mheskey3k@apache.org    Male
# 4312    4313      Chere       Brixey       cbrixey8o@apache.org  Female
# 4400    4401       Kerr       Bernth       kbernthb4@apache.org    Male
# ...

# %%
bygender = df2['gender']
bygender = bygender.value_counts().reset_index()
bygender
# Out:
#    gender  count
# 0    Male     13
# 1  Female      8

# %% [markdown]
# Task 3

# %%
df3 = df[ (df['gender'] == 'Male') & (df['salary'] > 1000000)].shape[0]
df3
# Out:
# 2848

# %% [markdown]
# Task 4

# %%
df4 = df[ (df['gender'] == 'Female') & (df['state'] == 'Alabama') & (df['salary'] < 800000) ]
df4.rename(columns = {'first_name' : 'FirstName', 'last_name' : 'LastName', 'salary':'Salary'})
# Out:
#           id   FirstName     LastName                          email  gender  \
# 11        12     Ronalda    Southcott        rsouthcottb@nytimes.com  Female
# 172      173        Ilka       Stucke         istucke4s@edublogs.org  Female
# 326      327       Monah       Cayton     mcayton92@domainmarket.com  Female
# 371      372       Helsa      Aartsen          haartsenab@weebly.com  Female
# 730      731      Dannie     Riccardo         driccardoka@dyndns.org  Female
# 916      917       Lilia      Sappell           lsappellpg@wikia.com  Female
# 947      948       Honey  Della Scala      hdellascalaqb@samsung.com  Female
# 1033    1034     Brianne  Rattenberie    brattenberiex@xinhuanet.com  Female
# 1177    1178       Kasey        Biles                 kbiles4x@is.gd  Female
# 1486    1487        Erma  Matuszinski      ematuszinskidi@cpanel.net  Female
# 1633    1634       Daryl       Assard          dassardhl@godaddy.com  Female
# ...

# %% [markdown]
# Task 5

# %%
df5 = df[ (df['state'] == 'Texas') & (df['email'].str.endswith('@hotmail.com'))].shape[0]
display(df5)
# Out:
# 0

# %% [markdown]
# Task 6

# %%
df6 = df[ (df['gender'] == 'Male') & (df['state'] == 'California') & (400000 < df['salary']) & (df['salary'] < 900000) ]
df6
# Out:
#           id first_name  last_name                          email gender  \
# 49        50     August  D'Ambrosi        adambrosi1d@jiathis.com   Male
# 157      158  Francklyn       Eake              feake4d@imgur.com   Male
# 204      205      Ferdy   Dumbrall           fdumbrall5o@tamu.edu   Male
# 206      207      Cesar      Agott  cagott5q@networksolutions.com   Male
# 592      593       Meir    Ughelli        mughelligg@yolasite.com   Male
# ...      ...        ...        ...                            ...    ...
# 11211  11212     Peyter   Sedgwick            psedgwick5x@npr.org   Male
# 11337  11338    Riordan   Burleigh             rburleigh9f@i2i.jp   Male
# 11349  11350    Conrade   Djakovic     cdjakovic9r@wikispaces.com   Male
# 11412  11413   Anatollo     Fearon            afearonbi@fotki.com   Male
# 11627  11628    Gerrard     Bridge  gbridgehh@creativecommons.org   Male
#
#        salary       state
# 49     741351  California
# 157    699509  California
# ...

# %% [markdown]
# Task 7

# %%
df7 = df[ (df['gender'] == 'Female') & (df['state'] == 'New York') & (df['salary'] > 500000)].shape[0]
df7
# Out:
# 267

# %% [markdown]
# Task 8

# %%
df8 = df[ (df['state'] == 'Georgia')][['first_name','last_name','salary']].sort_values(by = 'salary', ascending=False)
df8.head(10).rename(columns = {'first_name' : 'FirstName', 'last_name' : 'LastName', 'salary':'Salary'})
# Out:
#       FirstName  LastName   Salary
# 7635    Susette    Emeney  1999095
# 2330    Emeline     Bebis  1997605
# 4951       Evyn   Watkins  1994162
# 6008    Hillyer    Praton  1993907
# 658    Robinett     Mucci  1989791
# 46       Verile   Binding  1985757
# 9490  Harriette   Bonwick  1970839
# 739       Anita    Vowles  1965112
# 4081      Tiffi  Lansdown  1962952
# 3262    Haslett     Nevin  1960207

# %% [markdown]
# Task 9

# %%
df9 = df[ (df['last_name']).str.startswith('S') & (df['salary'] > 300000) ].shape[0]
df9
# Out:
# 951

# %% [markdown]
# Task 10

# %%
df10 = df[ (df['gender'] == 'Female') & (df['state'] == 'Oklahoma')][['salary']].mean()
df10.__round__(2)
# Out:
# salary    1020987.72
# dtype: float64

# %% [markdown]
# Task 11

# %%
df11 = df[ (df['state'] == 'Florida') & (df['email'].str.endswith('.net')) ]
df11
# Out:
#           id    first_name    last_name                         email  gender  \
# 327      328          Coop     Chaimson   cchaimson93@themeforest.net    Male
# 818      819          Jobi      Cutmere         jcutmeremq@cpanel.net  Female
# 924      925         Chris     Garfirth       cgarfirthpo@behance.net  Female
# 1101    1102         Waite    Rudderham       wrudderham2t@seesaa.net    Male
# 1242    1243            Em      Graffin      egraffin6q@clickbank.net  Female
# 1357    1358     Patrizius   Matskevich     pmatskevich9x@comcast.net    Male
# 1718    1719       Malanie      Harkins         mharkinsjy@seesaa.net  Female
# 1767    1768         Abbie       Isenor             aisenorlb@php.net    Male
# 1996    1997       Eugenio      Halhead         ehalheadro@discuz.net    Male
# 2515    2516         Hobey      Licence            hlicenceeb@ovh.net    Male
# 3622    3623        Fallon        Bothe               fbotheha@a8.net  Female
# ...

# %% [markdown]
# Task 12

# %%
df12 = df[ (df['first_name'].str.startswith('K')) & (df['salary'] > 1_000_000) ].shape[0]
df12
# Out:
# 243

# %% [markdown]
# Task 13

# %%
df13 = df[ (df['email'].str.contains('gmail.com')) & (df['salary'] < 200000) ]
df13
# Out:
# Empty DataFrame
# Columns: [id, first_name, last_name, email, gender, salary, state]
# Index: []

# %% [markdown]
# Task 14

# %%
df14 = df[ (df['gender'] == 'Male') & (df['state'] == 'Ohio') ].sort_values(by = 'salary').head(1)
df14
# Out:
#         id first_name last_name                email gender  salary state
# 6366  6367     Godard   Hillock  ghillocka6@etsy.com   Male   19860  Ohio

# %% [markdown]
# Task 15

# %%
df15 = df[ (df['gender'] == 'Female') & (df['state'] == 'California') & (df['salary'] > 800_000) ].shape[0]
df15
# Out:
# 400

# %% [markdown]
# Task 16

# %%
df16 = df[ (df['gender'] == 'Male') & (df['salary'] > 1_200_000) ][['last_name','salary']]
df16
# Out:
#         last_name   salary
# 19         Dunbar  1424714
# 24      Willshear  1727275
# 53          Chick  1213441
# 63         Persey  1752514
# 66        Redolfi  1337608
# ...           ...      ...
# 11632    Sperwell  1916655
# 11634      Carney  1212833
# 11636  Sitlington  1911043
# 11642        Iles  1607225
# 11648    Buchanan  1271538
#
# [2262 rows x 2 columns]

# %% [markdown]
# Task 17

# %%
df17 = df[ (df['email'].str.contains('edu')) & (df['salary'] > 1_500_000) ]
df17
# Out:
#           id first_name   last_name                      email  gender  \
# 10        11       Addi   Rucklesse      arucklessea@upenn.edu  Female
# 72        73   Granthem   Essberger  gessberger20@illinois.edu    Male
# 100      101        Gun      Cutler     gcutler2s@virginia.edu    Male
# 150      151     Caresa       Takis      ctakis46@illinois.edu  Female
# 235      236  Gaultiero      Duddle       gduddle6j@utexas.edu    Male
# ...      ...        ...         ...                        ...     ...
# 11383  11384        Nye      Cloutt          nclouttap@mit.edu    Male
# 11402  11403     Sylvia     Millins         smillinsb8@umn.edu  Female
# 11554  11555        Von    McKinnon         vmckinnonfg@si.edu    Male
# 11602  11603     Krissy    Goosnell      kgoosnellgs@upenn.edu  Female
# 11636  11637      Kirby  Sitlington    ksitlingtonhq@umich.edu    Male
#
#         salary                 state
# 10     1811361              New York
# 72     1587610            New Jersey
# ...

# %% [markdown]
# Task 18

# %%
df18 = df[ (df['state'] == 'Alabama') & (df['salary'] < 100_000) ]
df18
# Out:
#         id first_name last_name                   email  gender  salary  \
# 730    731     Dannie  Riccardo  driccardoka@dyndns.org  Female   78730
# 916    917      Lilia   Sappell    lsappellpg@wikia.com  Female   18515
# 4524  4525      Penni   Perrett    pperrettek@europa.eu  Female   64526
# 5627  5628      Ethan    Telfer   etelferhf@tinypic.com    Male   88161
# 6029  6030       Roda     Ollet        rollett@digg.com  Female   33092
#
#         state
# 730   Alabama
# 916   Alabama
# 4524  Alabama
# 5627  Alabama
# 6029  Alabama

# %% [markdown]
# Task 19

# %%
df19 = df[ (df['last_name'].str.endswith('n')) & (df['salary'] > 600_000) ]
df19
# Out:
#           id first_name   last_name                             email  gender  \
# 22        23    Gilburt      Metson              gmetsonm@cornell.edu    Male
# 26        27    Raymund    Dodgshon    rdodgshonq@cargocollective.com    Male
# 42        43    Auroora     Startin               astartin16@webs.com  Female
# 65        66      Deana      Gerran            dgerran1t@columbia.edu  Female
# 67        68   Lauretta     Creavin              lcreavin1v@patch.com  Female
# ...      ...        ...         ...                               ...     ...
# 11629  11630     Gorden     Flatman             gflatmanhj@paypal.com    Male
# 11636  11637      Kirby  Sitlington           ksitlingtonhq@umich.edu    Male
# 11638  11639       Ania     Scotson              ascotsonhs@wiley.com  Female
# 11647  11648      Avrit      Bastin            abastini1@symantec.com  Female
# 11648  11649   Papageno    Buchanan  pbuchanani2@pagesperso-orange.fr    Male
#
#         salary         state
# ...

# %% [markdown]
# Task 20

# %%
df20 = df[ (df['state'] == 'District of Columbia') ].sort_values(by = 'salary', ascending=False).head(1)
df20
# Out:
#         id first_name last_name                       email gender   salary  \
# 9386  9387      Bryan     Boddy  bboddyar@timesonline.co.uk   Male  1997136
#
#                      state
# 9386  District of Columbia

# %% [markdown]
# Task 21

# %%
df21 = df[ (df['gender'] == 'Female') & (df['state'] == 'New York') & (500_000 < df['salary']) & (df['salary'] < 1_000_000) ]
df21
# Out:
#           id  first_name      last_name                             email  \
# 42        43     Auroora        Startin               astartin16@webs.com
# 81        82  Anna-diana           Lean                alean29@oracle.com
# 173      174        Erma         Grimes              egrimes4t@senate.gov
# 174      175     Allissa         Degoey                adegoey4u@1688.com
# 193      194      Imogen  De la Yglesia       idelayglesia5d@slashdot.org
# ...      ...         ...            ...                               ...
# 10980  10981    Lizabeth      Corneille  lcorneillera@cargocollective.com
# 11069  11070       Bride        Tennock              btennock1z@skype.com
# 11115  11116    Rosmunda        Rolston            rrolston39@yahoo.co.jp
# 11473  11474     Teriann         Gawler         tgawlerd7@telegraph.co.uk
# 11622  11623    Margaret        Sleicht             msleichthc@forbes.com
#
#        gender  salary     state
# 42     Female  612491  New York
# ...

# %% [markdown]
# Task 22

# %%
df22 = df[ (df['state'] == 'Texas') & (df['email'].str.contains('yahoo.com')) ].shape[0]
df22
# Out:
# 1

# %% [markdown]
# Task 23

# %%
avForCalifornia = df[ (df['gender'] == 'Male') & (df['state'] == "California") ][['salary']]
# avForCalifornia['salary'].mean()
df23 = df[ (df['gender'] == 'Male') & (df['state'] == "California") & (df['salary'] < avForCalifornia['salary'].mean()) ]
df23
# Out:
#           id first_name  last_name                          email gender  \
# 7          8       Jone     Pegden        jpegden7@washington.edu   Male
# 49        50     August  D'Ambrosi        adambrosi1d@jiathis.com   Male
# 86        87     Emmott    Smeeton      esmeeton2e@guardian.co.uk   Male
# 157      158  Francklyn       Eake              feake4d@imgur.com   Male
# 204      205      Ferdy   Dumbrall           fdumbrall5o@tamu.edu   Male
# ...      ...        ...        ...                            ...    ...
# 11412  11413   Anatollo     Fearon            afearonbi@fotki.com   Male
# 11427  11428     Pepito      Asaaf            pasaafbx@seesaa.net   Male
# 11453  11454     Tammie    Whybray              twhybraycn@un.org   Male
# 11504  11505     Morten    Biddiss               mbiddisse2@ow.ly   Male
# 11627  11628    Gerrard     Bridge  gbridgehh@creativecommons.org   Male
#
#        salary       state
# 7      327962  California
# 49     741351  California
# ...
